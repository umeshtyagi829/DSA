# %%
def umesh(j):
    x = 0
    for i in range(j):
        x = i+x
    print(x)
    print(i)

# %%
umesh(11)
# Out:
# 55
# 10

# %%
# %timeit umesh(10)
# Out:
# 45
# 9
# 45
# 9
# 45
# 9
# 45
# 9
# 45
# 9
# 45
# 9
# 45
# 9
# 45
# 9
# 45
# 9
# 45
# 9
# 45
# 9
# 45
# 9
# 45
# 9
# 45
# 9
# 45
# 9
# 45
# 9
# 45
# 9
# 45
# 9
# 45
# 9
# 45
# 9
# 45
# 9
# 45
# 9
# 45
# 9
# 45
# 9
# 45
# 9
# 45
# 9
# 45
# 9
# 45
# 9
# 45
# 9
# 45
# 9
# 45
# 9
# 45
# 9
# 45
# 9
# 45
# 9
# 45
# 9
# 45
# 9
# 45
# 9
# 45
# 9
# 45
# 9
# 45
# 9
# 45
# 9
# 45
# 9
# 45
# 9
# 45
# 9
# 45
# 9
# 45
# 9
# 45
# 9
# 45
# 9
# 45
# 9
# 45
# 9
# 45
# 9
# 45
# 9
# 45
# 9
# 45
# 9
# 45
# 9
# 45
# 9
# 45
# 9
# 45
# 9
# 45
# 9
# 45
# 9
# 45
# 9
# 45
# 9
# 45
# 9
# 45
# 9
# 45
# 9
# 45
# 9
# 45
# 9
# 45
# 9
# 45
# 9
# 45
# 9
# 45
# 9
# 45
# 9
# 45
# 9
# 45
# 9
# 45
# 9
# 45
# 9
# 45
# 9
# 45
# 9
# 45
# 9
# 45
# 9
# 45
# 9
# 45
# 9
# 45
# 9
# 45
# 9
# 45
# 9
# 45
# 9
# 45
# 9
# 45
# 9
# 45
# 9
# 45
# 9
# 45
# 9
# 45
# 9
# 45
# 9
# 45
# 9
# 45
# 9
# 45
# 9
# 45
# 9
# 45
# 9
# 45
# 9
# 45
# 9
# 45
# 9
# 45
# 9
# 45
# 9
# 45
# 9
# 45
# 9
# 45
# 9
# 45
# 9
# 45
# 9
# 45
# 9
# 45
# 9
# 45
# 9
# ...

# %%
# %load_ext line_profiler
# Out:
# The line_profiler extension is already loaded. To reload it, use:
#   %reload_ext line_profiler

# %%
# %lprun -f umesh umesh(10)
# Out:
# 45
# 9

# %%
def umesh2(n):
    x = n * (n+1)/2
    return x

# %%
# %lprun -f umesh2 umesh2(10)

# %%
f = umesh2(10)

# %%
print(f)
# Out:
# 55.0

# %%
umesh2(10)
# Out:
# 55.0
